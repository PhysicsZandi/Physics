# %%
from ER_phase_transitions import *

# %% [markdown]
# Run 1 (N = 10, #=10)

# %%
nodes_run_1 = 10
copies_run_1 = 10

# %%
run_1 = ER_networks(nodes_run_1, copies_run_1)
run_1.set_probabilities()
run_1.set_copies()
run_1.set_nodes_and_links()
run_1.set_giant_component()
run_1.set_averages()
# Out:
# ...
# 100%|██████████| 10/10 [00:00<00:00, 571.91it/s]

# %%
run_1.plot_networks()
run_1.plot_giant_components()

# %%
run_1.print_threshold_and_critical_point()
run_1.plot_nodes_and_links()
run_1.plot_giant_component_properties()
run_1.plot_averages()
# Out:
# The threshold is  0.23025850929940458
# The critical probability is  0.1

# %% [markdown]
# Run 1.1 (N=10, #=100)

# %%
nodes_run_11 = 10
copies_run_11 = 100

# %%
run_11 = ER_networks(nodes_run_11, copies_run_11)
run_11.set_probabilities()
run_11.set_copies()
run_11.set_nodes_and_links()
run_11.set_giant_component()
run_11.set_averages()
# Out:
# ...
# 100%|██████████| 100/100 [00:00<00:00, 669.73it/s]

# %%
run_11.plot_networks()
run_11.plot_giant_components()

# %%
run_11.print_threshold_and_critical_point()
run_11.plot_nodes_and_links()
run_11.plot_giant_component_properties()
run_11.plot_averages()
# Out:
# The threshold is  0.23025850929940458
# The critical probability is  0.1

# %% [markdown]
# Run 2 (N=100)

# %%
nodes_run_2 = 100
copies_run_2 = 10

# %%
run_2 = ER_networks(nodes_run_2, copies_run_2)
run_2.set_probabilities()
run_2.set_copies()
run_2.set_nodes_and_links()
run_2.set_giant_component()
run_2.set_averages()
# Out:
# ...
# 100%|██████████| 10/10 [00:00<00:00, 16.72it/s]

# %%
run_2.plot_networks()
run_2.plot_giant_components()

# %%
run_2.print_threshold_and_critical_point()
run_2.plot_nodes_and_links()
run_2.plot_giant_component_properties()
run_2.plot_averages()
# Out:
# The threshold is  0.04605170185988092
# The critical probability is  0.01

# %% [markdown]
# Run 2.1 (N=100, #=50)

# %%
nodes_run_21 = 100
copies_run_21 = 50

# %%
run_21 = ER_networks(nodes_run_21, copies_run_21)
run_21.set_probabilities()
run_21.set_copies()
run_21.set_nodes_and_links()
run_21.set_giant_component()
run_21.set_averages()
# Out:
# ...
# 100%|██████████| 50/50 [00:02<00:00, 17.44it/s]

# %%
run_21.plot_networks()
run_21.plot_giant_components()

# %%
run_21.print_threshold_and_critical_point()
run_21.plot_nodes_and_links()
run_21.plot_giant_component_properties()
run_21.plot_averages()
# Out:
# The threshold is  0.04605170185988092
# The critical probability is  0.01

# %% [markdown]
# Run 3 (N=1000)

# %%
nodes_run_3 = 1000
copies_run_3 = 10

# %%
run_3 = ER_networks(nodes_run_3, copies_run_3)
run_3.set_probabilities()
run_3.set_copies()
run_3.set_nodes_and_links()
run_3.set_giant_component()
run_3.set_averages()
# Out:
# ...
# 100%|██████████| 10/10 [01:24<00:00,  8.44s/it]

# %%
run_3.plot_networks()
run_3.plot_giant_components()

# %%
run_3.print_threshold_and_critical_point()
run_3.plot_nodes_and_links()
run_3.plot_giant_component_properties()
run_3.plot_averages()
# Out:
# The threshold is  0.006907755278982137
# The critical probability is  0.001
